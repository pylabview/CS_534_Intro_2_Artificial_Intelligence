# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # Options: 0 = all, 1 = filter INFO, 2 = filter WARNING, 3 = ERROR only
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"  # disable GPU

import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        # Set memory growth to True
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# 2025-07-11 18:34:09.852780: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752284049.861775  335896 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752284049.864388  335896 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1752284049.871170  335896 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752284049.871178  335896 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752284049.871179  335896 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1752284049.871180  335896 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
# !nvidia-smi
# Out:
# Fri Jul 11 18:34:11 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 565.77                 Driver Version: 565.77         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4070 ...    Off |   00000000:01:00.0  On |                  N/A |
# | N/A   42C    P8              3W /  115W |     796MiB /   8188MiB |     21%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      3935      G   /usr/lib/xorg/Xorg                            281MiB |
# |    0   N/A  N/A      4023    C+G   ...libexec/gnome-remote-desktop-daemon        128MiB |
# |    0   N/A  N/A      4076      G   /usr/bin/gnome-shell                           44MiB |
# |    0   N/A  N/A      8324      G   ...seed-version=20250709-180034.548000        118MiB |
# |    0   N/A  N/A     13376      G   gnome-control-center                            2MiB |
# |    0   N/A  N/A     46343    C+G   cosmic-term                                    81MiB |
# +-----------------------------------------------------------------------------------------+

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from seaborn import heatmap

from sklearn.metrics import classification_report, ConfusionMatrixDisplay, \
accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# New libraries
from tensorflow.keras import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(patience=3)

# %%
from sklearn.metrics import confusion_matrix
def eval_classification(model, X, y, name='model', labels=None):
    """Prints a classification report and confusion matrix
    Returns a dataframe with classification metrics.
    """
    preds = np.rint(model.predict(X))

    print(classification_report(y, preds, target_names=labels))

    # Display confusion matrix
    ConfusionMatrixDisplay.from_predictions(y, preds, display_labels=labels)
    plt.show()

    # Compute confusion matrix for FPR and FNR
    tn, fp, fn, tp = confusion_matrix(y, preds).ravel()

    # Initialize the score dataframe
    score_df = pd.DataFrame(index=[name])
    score_df.loc[name, 'Accuracy'] = accuracy_score(y, preds)
    score_df.loc[name, 'Precision'] = precision_score(y, preds)
    score_df.loc[name, 'Recall'] = recall_score(y, preds)
    score_df.loc[name, 'F1 Score'] = f1_score(y, preds)
    score_df.loc[name, 'False Positive Rate'] = fp / (fp + tn) if (fp + tn) > 0 else 0
    score_df.loc[name, 'False Negative Rate'] = fn / (fn + tp) if (fn + tp) > 0 else 0

    return score_df

def plot_history(history):
  print("""Takes a keras model learning history and plots each metric""")

  metrics = history.history.keys()
  print(metrics)
  for metric in metrics:
      if not 'val' in metric:
        plt.plot(history.history[f'{metric}'], label=f'{metric}')
        if f'val_{metric}' in metrics:
          plt.plot(history.history[f'val_{metric}'], label=f'val_{metric}')
        plt.legend()
        plt.title(f'{metric}')
        plt.show()

# %% [markdown]
# ### Classification:
# Classification models are similar, except that we need to adjust the final activation of the output layer, the loss function in the compile step, and the metrics we use to judge them. Remember: MAE, MSE, RMSE, and R2 are regression metrics, accuracy, recall, precision, F1-Score, and confusion matrices are classification metrics.

# %%
df_train = pd.read_csv('Split_Data/Model_Ready/train.csv')
df_train.head()
# Define X and y and train data
X_train = df_train.drop(columns = 'label')
y_train = df_train['label']

# %%
df_val = pd.read_csv('Split_Data/Model_Ready/val.csv')

# Define X and y and train data
X_val = df_val.drop(columns = 'label')
y_val = df_val['label']

# %%
df_val.shape
# Out:
# (13197, 144)

# %%
df_train.shape
# Out:
# (52792, 144)

# %% [markdown]
# ### Build de Model

# %%
# Define the input shape
input_shape = (X_train.shape[1],)

class_model1 = Sequential([
    Input(shape=input_shape),
    Dense(10, activation='relu'),
    Dense(10, activation='relu'),
    Dense(1, activation='sigmoid')  # binary classification
])
# Out:
# I0000 00:00:1752284060.405687  335896 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5347 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
# Compile your model

# Since this is binary classification set loss  = 'binary_crossentropy'
# Set the metrics = ['acc']
class_model1.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['acc'])

# %%
# fit your model
history = class_model1.fit(X_train, y_train,
                        validation_data = (X_val, y_val),
                        epochs = 500,
                        verbose=0,
                          callbacks=[early_stopping])
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752284063.339487  336276 service.cc:152] XLA service 0x76bc98003760 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1752284063.339499  336276 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Laptop GPU, Compute Capability 8.9
# I0000 00:00:1752284063.430881  336276 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1752284063.773265  336276 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.

# %%
# See how your model is doing
plot_history(history)
# Out:
# Takes a keras model learning history and plots each metric
# dict_keys(['acc', 'loss', 'val_acc', 'val_loss'])

# %%
# Make predicitons and evaluate your model
# Define labels for the confusion matrix
labels = ['No Phishing Email', 'Phishing Email']

# Evaluate training set
print('Training Evaluation:\n')
train_scores = eval_classification(class_model1,
                             X_train, y_train,
                             name='class_model1 train',
                             labels=labels)
print('Val Evaluation:\n')
# Confusion Matrix
val_scores = (eval_classification(class_model1,
                                           X_val, y_val,
                                           name='class_model1 val',
                                           labels=labels))

scores = pd.concat([train_scores, val_scores])
scores
# Out:
# Training Evaluation:
#
# 1650/1650 ━━━━━━━━━━━━━━━━━━━━ 1s 404us/step
#                    precision    recall  f1-score   support
#
# No Phishing Email       0.99      0.99      0.99     25308
#    Phishing Email       0.99      0.99      0.99     27484
#
#          accuracy                           0.99     52792
#         macro avg       0.99      0.99      0.99     52792
#      weighted avg       0.99      0.99      0.99     52792
# Val Evaluation:
#
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step
#                    precision    recall  f1-score   support
#
# No Phishing Email       0.98      0.98      0.98      6301
#    Phishing Email       0.98      0.98      0.98      6896
#
#          accuracy                           0.98     13197
#         macro avg       0.98      0.98      0.98     13197
#      weighted avg       0.98      0.98      0.98     13197
#                     Accuracy  Precision    Recall  F1 Score  \
# class_model1 train  0.988123   0.989038  0.988139  0.988588
# class_model1 val    0.980526   0.980043  0.982744  0.981392
#
#                     False Positive Rate  False Negative Rate
# class_model1 train             0.011893             0.011861
# class_model1 val               0.021901             0.017256
